# %% [markdown]
# # Car Features Data Analysis Project
#
# ## Problem Statement
# This project aims to perform an in-depth Exploratory Data Analysis (EDA) on a dataset containing various car features to understand its underlying structure, identify patterns, anomalies, and relationships between variables. The insights gained will be crucial for subsequent tasks such as predictive modeling of car prices or market analysis.
#
# ## Project Overview
# This notebook details the process of loading, cleaning, transforming, and visualizing car feature data. It covers initial data inspection, handling missing values and duplicates, and exploring feature distributions and correlations to derive actionable insights.
#
# ## Tools Used
# *   **Python**: Programming language
# *   **pandas**: Data manipulation and analysis
# *   **matplotlib**: Data visualization
# *   **seaborn**: Enhanced data visualization
# *   **missingno**: Visualizing missing data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Data Loading
#
# The dataset `CarFeatures.csv` is loaded from Google Drive into a pandas DataFrame. Ensure the CSV file is accessible at the specified path.

# %%
path = '/content/gdrive/MyDrive/Colab Notebooks/UCW/files/CarFeatures.csv'

# %% [markdown]
# ## Importing Required Libraries
#
# Essential Python libraries for data manipulation, analysis, and visualization are imported.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the Dataset
#
# The `CarFeatures.csv` file is loaded into a pandas DataFrame named `df`.

# %%
df = pd.read_csv(path)

# %% [markdown]
# ## Initial Data Inspection
#
# To get a first glance at the data, the `head()` and `tail()` functions are used to display the first and last few rows of the DataFrame, providing a quick overview of its structure and content.

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# ## Descriptive Statistics
#
# The `describe()` function provides a statistical summary of the numerical columns in the DataFrame, including count, mean, standard deviation, min, max, and quartiles. This helps in understanding the central tendency, dispersion, and shape of the data's distribution.

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %% [markdown]
# ## Concise Data Summary
#
# The `info()` method prints a concise summary of the DataFrame, including the index dtype and column dtypes, non-null values, and memory usage. This is vital for quickly identifying missing values and confirming data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %% [markdown]
# ## Data Dimensions (Shape)
#
# The `shape` attribute returns a tuple representing the dimensions of the DataFrame (number of rows, number of columns).

# %%
df.shape
# Out:
# (11914, 16)

# %% [markdown]
# ## Listing All Features
#
# The `columns` attribute provides a list of all column names (features) present in the DataFrame.

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %% [markdown]
# ## Visualizing Missing Values
#
# The `missingno` library is used to visualize the completeness of the dataset, making it easy to spot columns with missing data and their patterns. A sample of 250 rows is used for better visualization clarity.

# %%
import missingno as msno
msno.matrix(df.sample(250))
# Out:
# <Axes: >

# %% [markdown]
# ## Checking Data Types
#
# It's crucial to verify the data types of each column to ensure they are appropriate for analysis. For instance, numerical columns like 'Price' should be `int` or `float` to enable mathematical operations.

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# ## Data Cleaning: Dropping Irrelevant Columns
#
# Columns that are deemed irrelevant for the analysis or future modeling (e.g., 'Engine Fuel Type', 'Market Category', 'Vehicle Style', 'Popularity', 'Number of Doors', 'Vehicle Size') are dropped to streamline the dataset and focus on more impactful features.

# %%
df = df.drop(['Engine Fuel Type', 'Market Category', 'Vehicle Style', 'Popularity', 'Number of Doors', 'Vehicle Size'], axis=1)
df.head(5)
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#       Driven_Wheels  highway MPG  city mpg   MSRP
# 0  rear wheel drive           26        19  46135
# 1  rear wheel drive           28        19  40650
# 2  rear wheel drive           28        20  36350
# 3  rear wheel drive           28        18  29450
# 4  rear wheel drive           28        18  34500

# %% [markdown]
# ## Data Cleaning: Renaming Columns
#
# For improved readability and ease of use, several column names are renamed to more concise and intuitive labels.

# %%
df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
df.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders Transmission        Drive Mode  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
#
#    MPG-H  MPG-C  Price
# 0     26     19  46135
# 1     28     19  40650
# 2     28     20  36350
# 3     28     18  29450
# 4     28     18  34500

# %% [markdown]
# ## Data Cleaning: Handling Duplicate Rows
# Duplicate entries in the dataset can skew analysis results. This step identifies and removes duplicate rows to ensure data integrity.

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (989, 10)

# %% [markdown]
# ## Counting Rows Before Duplicate Removal
#
# To quantify the impact of duplicate removal, the number of rows is counted before the duplicates are dropped.

# %%
df.count()      # Used to count the number of rows
# Out:
# Make            11914
# Model           11914
# Year            11914
# HP              11845
# Cylinders       11884
# Transmission    11914
# Drive Mode      11914
# MPG-H           11914
# MPG-C           11914
# Price           11914
# dtype: int64

# %% [markdown]
# Approximately 989 duplicate rows were identified and removed, reducing the dataset size from 11914 to 10925 entries.

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders Transmission        Drive Mode  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
#
#    MPG-H  MPG-C  Price
# 0     26     19  46135
# 1     28     19  40650
# 2     28     20  36350
# 3     28     18  29450
# 4     28     18  34500

# %%
df.count()
# Out:
# Make            10925
# Model           10925
# Year            10925
# HP              10856
# Cylinders       10895
# Transmission    10925
# Drive Mode      10925
# MPG-H           10925
# MPG-C           10925
# Price           10925
# dtype: int64

# %% [markdown]
# ## Data Cleaning: Handling Missing Values
#
# Missing values are identified using `isnull().sum()`. For this dataset, as the number of missing values in 'HP' and 'Cylinders' is relatively small compared to the total dataset size (less than 1%), these rows are dropped to maintain data quality.

# %%
print(df.isnull().sum())
# Out:
# Make             0
# Model            0
# Year             0
# HP              69
# Cylinders       30
# Transmission     0
# Drive Mode       0
# MPG-H            0
# MPG-C            0
# Price            0
# dtype: int64

# %% [markdown]
# The count of non-null values for 'HP' and 'Cylinders' before dropping was 10856 and 10895 respectively out of 10925 rows, indicating the presence of missing values.

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Make            10827
# Model           10827
# Year            10827
# HP              10827
# Cylinders       10827
# Transmission    10827
# Drive Mode      10827
# MPG-H           10827
# MPG-C           10827
# Price           10827
# dtype: int64

# %% [markdown]
# After dropping rows with missing values, the dataset now contains 10827 complete entries, ensuring all remaining data is valid for analysis.

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# Make            0
# Model           0
# Year            0
# HP              0
# Cylinders       0
# Transmission    0
# Drive Mode      0
# MPG-H           0
# MPG-C           0
# Price           0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA): Detecting Outliers
#
# Outliers, data points significantly different from others, can affect statistical models. Box plots are used to visually identify outliers in key numerical features such as 'Price', 'HP', and 'Cylinders'.

# %%
sns.boxplot(y=df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.boxplot(y=df['HP'])
# Out:
# <Axes: ylabel='HP'>

# %%
sns.boxplot(y=df['Cylinders'])
# Out:
# <Axes: ylabel='Cylinders'>

# %% [markdown]
# ## Exploratory Data Analysis (EDA): Histograms
#
# Histograms are used to visualize the distribution of categorical data, specifically to show the frequency of cars by 'Make'. This helps in understanding the market share or representation of different car manufacturers in the dataset.

# %%
df.Make.value_counts().nlargest(20).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make');

# %% [markdown]
# ## Exploratory Data Analysis (EDA): Count Plots and Pie Chart
#
# Count plots provide a visualization of the frequency of categorical variables. Here, `Make`, `Transmission`, and `Drive Mode` distributions are explored to understand the prevalence of different car attributes. A pie chart is used for `Drive Mode` to show proportions.

# %%
ax = sns.countplot(x=df["Make"])
ax.tick_params(axis='x', rotation=90)

# %%
ax = sns.countplot(x=df["Transmission"])

# %%
trans_counts = df["Drive Mode"].value_counts()
trans_counts
# Out:
# front wheel drive    4168
# rear wheel drive     3120
# all wheel drive      2281
# four wheel drive     1258
# Name: Drive Mode, dtype: int64

# %%
plt.pie(trans_counts, labels=trans_counts.index, autopct='%1.0f%%')
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis (EDA): Heat Maps for Correlation Analysis
#
# Heat maps are effective tools for visualizing the correlation matrix between numerical features. This helps in identifying strongly correlated variables, which is crucial for understanding dependencies and for feature selection in modeling. It reveals that `Price` is strongly correlated with `HP` and `Cylinders`.

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# <ipython-input-41-a44b43776930>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
#                Year        HP  Cylinders     MPG-H     MPG-C     Price
# Year       1.000000  0.314971  -0.050598  0.284237  0.234135  0.196789
# HP         0.314971  1.000000   0.788007 -0.420281 -0.473551  0.659835
# Cylinders -0.050598  0.788007   1.000000 -0.611576 -0.632407  0.554740
# MPG-H      0.284237 -0.420281  -0.611576  1.000000  0.841229 -0.209150
# MPG-C      0.234135 -0.473551  -0.632407  0.841229  1.000000 -0.234050
# Price      0.196789  0.659835   0.554740 -0.209150 -0.234050  1.000000

# %% [markdown]
# ## Exploratory Data Analysis (EDA): Scatter Plots
#
# Scatter plots are used to visualize the relationship between two numerical variables. A scatter plot of 'HP' versus 'Price' helps to observe if there's a linear or non-linear trend, indicating how horsepower influences car price.

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['HP'], df['Price'])
ax.set_xlabel('HP')
ax.set_ylabel('Price')
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis (EDA): Feature Distributions
#
# Further exploration into the distribution of individual features like 'HP' is done using `distplot` (from seaborn) and `hist` (from matplotlib) to assess normality and spread. `pairplot` provides a matrix of scatter plots for pairwise relationships and histograms/KDE for univariate distributions of selected features. Box plots and violin plots visualize the relationship between categorical ('Cylinders') and numerical ('HP', 'Price') features, highlighting value distributions and potential outliers across categories.

# %%
import scipy.stats as st

# %%
y = df['HP']
plt.figure(1); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)
# Out:
# <ipython-input-46-9ffb68a46d00>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y, kde=False, fit=st.norm)
# <Axes: title={'center': 'Normal'}, xlabel='HP'>

# %%
plt.hist(df['HP'],orientation = 'vertical',histtype = 'bar', color ='blue')
plt.show()

# %%
sns.pairplot(df,size = 2 ,kind ='scatter',diag_kind='kde')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x="Cylinders", y="HP", data=df)
# Out:
# <Axes: xlabel='Cylinders', ylabel='HP'>

# %%
sns.boxplot(x="Cylinders", y="Price", data=df)
# Out:
# <Axes: xlabel='Cylinders', ylabel='Price'>

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.violinplot(x="Cylinders", y="HP", data=df)
# Out:
# <Axes: xlabel='Cylinders', ylabel='HP'>

# %%
Conclusion and Key Insights

This project involved performing Exploratory Data Analysis (EDA) on a car features dataset containing over 11,000 vehicle records. Through data cleaning, preprocessing, and visualization, the dataset was refined into a reliable foundation for further analysis and predictive modeling.

Key Findings
Identified a strong positive relationship between horsepower, cylinders, and vehicle price, indicating these are major drivers of car valuation.
Detected outliers in key variables such as price and horsepower, highlighting areas that require attention before model development.
Analyzed manufacturer, transmission, and drive-mode distributions to better understand market trends and vehicle characteristics.
Improved data quality by removing duplicates, handling missing values, and retaining the most relevant features for analysis.
Business Impact

The analysis provided actionable insights into the factors influencing vehicle pricing and established a clean, well-structured dataset for future machine learning applications. These findings can support pricing strategies, market analysis, and predictive modeling initiatives in the automotive industry.
